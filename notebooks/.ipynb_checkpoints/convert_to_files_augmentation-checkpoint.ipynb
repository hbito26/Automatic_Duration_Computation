# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sc

import matplotlib.pyplot as plt
import h5py
import obspy
from obspy.signal.filter import envelope
from obspy.clients.fdsn import Client
from glob import glob #is a function that’s used to search for files that match a specific file pattern or name.
import random

from scipy import signal

# %% [markdown]
# ### Make a flipped data of the mixed waveforms

# %%
# Read the waveform data downsampled to 20 Hz for mixed waveforms
with h5py.File('mixed_signal_1min_norm.h5', 'r') as f:
    mixed_wave = f['quake'][:] # Add this pair of brakets to extract only the np array
    print(mixed_wave.shape)
# Out:
# (2000, 1, 1200)

# %%
cat_earthquake_test = pd.read_csv('highest_snrs_durations_peak_amp.csv')

# %%
# Make zeros to contain the mixed waveforms that is flipped
mixed_wave_flipped = np.zeros((2000,1,1200))

# %%
# Contain the flipped data into the zeros
for i in range(len(mixed_wave_flipped)):
    mixed_wave_flipped[i,0,:] = mixed_wave[i,0,:] * (-1)

# %%
# Make sure the waveforms are flipped
print(mixed_wave[0])
print(mixed_wave_flipped[0])

print(mixed_wave[100])
print(mixed_wave_flipped[100])
# Out:
# [[ 4.92026413e-04  4.61513536e-04  6.47166581e-04 ... -8.22560771e-01
#   -1.14980544e+00 -1.04702846e+00]]
# [[-4.92026413e-04 -4.61513536e-04 -6.47166581e-04 ...  8.22560771e-01
#    1.14980544e+00  1.04702846e+00]]
# [[-0.02381263 -0.02394575 -0.01058758 ... -1.79824997 -3.2047242
#    1.04613433]]
# [[ 0.02381263  0.02394575  0.01058758 ...  1.79824997  3.2047242
#   -1.04613433]]

# %%
cat_earthquake_test
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0    event_id  \
# 0                0             0      119605  uw61362346
# 1                1             1       58318  uw60563331
# 2                2             2      127484  uw61504942
# 3                3             3       19376  uw10753338
# 4                4             4       73030  uw60881241
# ...            ...           ...         ...         ...
# 1995          1995          1995        8697  uw10656733
# 1996          1996          1996       43232  uw10823553
# 1997          1997          1997      147871  uw61625752
# 1998          1998          1998      109477  uw61267487
# 1999          1999          1999        5161  uw10581343
#
#                source_origin_time  source_latitude_deg  source_longitude_deg  \
# 0     2018-01-03T08:36:25.940000Z               46.256              -122.056
# 1     2013-08-03T02:11:16.250000Z               46.327              -122.391
# 2     2018-11-19T11:09:13.050000Z               47.698              -123.552
# 3     2008-07-31T05:02:43.130000Z               48.152              -122.748
# 4     2014-09-17T10:06:12.840000Z               47.561              -123.009
# ...                           ...                  ...                   ...
# 1995  2005-07-02T22:39:31.040000Z               48.136              -122.482
# 1996  2011-09-04T04:13:39.540000Z               46.411              -119.260
# 1997  2020-06-03T17:13:50.350000Z               46.844              -121.762
# 1998  2017-05-18T18:15:32.560000Z               47.593              -122.589
# 1999  2003-02-27T06:40:44.880000Z               46.658              -121.860
#
#      source_type  source_depth_km  preferred_source_magnitude  ...  \
# 0     earthquake           10.230                        3.82  ...
# 1     earthquake           13.199                        3.12  ...
# 2     earthquake           39.320                        4.08  ...
# 3     earthquake           55.880                        3.87  ...
# 4     earthquake           16.201                        3.98  ...
# ...          ...              ...                         ...  ...
# 1995  earthquake           16.500                        2.20  ...
# 1996  earthquake            1.605                        3.21  ...
# 1997  earthquake            0.310                        1.10  ...
# 1998  earthquake           25.110                        2.50  ...
# 1999  earthquake            4.240                        2.10  ...
#
#      source_local_magnitude  source_local_magnitude_uncertainty  \
# 0                      3.82                               0.149
# 1                      3.12                               0.275
# 2                      4.08                               0.163
# 3                      3.87                               0.134
# 4                      3.98                               0.176
# ...                     ...                                 ...
# 1995                    NaN                                 NaN
# 1996                   3.21                               0.119
# 1997                   1.10                               0.098
# 1998                   2.50                               0.286
# 1999                    NaN                                 NaN
#
#       source_duration_magnitude  source_duration_magnitude_uncertainty  \
# 0                          4.20                                  0.306
# 1                          3.12                                  0.336
# 2                          4.11                                  0.349
# 3                          3.89                                  0.246
# 4                          4.14                                  0.325
# ...                         ...                                    ...
# 1995                       2.20                                  0.030
# 1996                       3.70                                  0.040
# 1997                       0.29                                  0.105
# 1998                       2.57                                  0.297
# 1999                       2.10                                  0.020
#
#      source_hand_magnitude trace_missing_channel trace_has_offset snr_final  \
# 0                      NaN                     0                0    76.523
# 1                      NaN                     0                0    73.933
# 2                      NaN                     0                0    73.801
# 3                      NaN                     0                0    73.368
# 4                      NaN                     0                0    73.215
# ...                    ...                   ...              ...       ...
# 1995                   NaN                     2                0    43.633
# 1996                   NaN                     0                0    43.632
# 1997                   NaN                     0                0    43.630
# 1998                   NaN                     0                0    43.629
# 1999                   NaN                     2                0    43.628
#
#       durations  durations_peak_amp
# 0         12.47               11.19
# 1          8.47                5.94
# 2         17.23               15.45
# 3         22.84               14.49
# 4          6.16                5.68
# ...         ...                 ...
# 1995      20.98               20.56
# 1996      14.04               11.16
# 1997       3.65                2.85
# 1998       9.74                5.69
# 1999      17.41               12.87
#
# [2000 rows x 43 columns]

# %%
# Make a file of the flipped waveforms
with h5py.File('mixed_signal_1min_norm_flip.h5', 'w') as f:
    f.create_dataset('quake', data=mixed_wave_flipped)
